# %%
import pandas as pd
from pybaseball import bwar_bat, bwar_pitch

bref_batting = bwar_bat()
bref_pitching = bwar_pitch()

# %%
bref_batting.columns
# Out:
# Index(['name_common', 'mlb_ID', 'player_ID', 'year_ID', 'team_ID', 'stint_ID',
#        'lg_ID', 'pitcher', 'G', 'PA', 'salary', 'runs_above_avg',
#        'runs_above_avg_off', 'runs_above_avg_def', 'WAR_rep', 'WAA', 'WAR'],
#       dtype='object')

# %%
filtered_bwar = bref_batting[(bref_batting['year_ID'] == 2025) & (bref_batting['pitcher'] == 'N') & (bref_batting['PA'] > 100)]
filtered_bwar = filtered_bwar[["name_common", "mlb_ID", "year_ID", "team_ID", "lg_ID", "G", "PA", "WAR"]]
filtered_bwar.iloc[0:50]
# Out:
#              name_common    mlb_ID  year_ID team_ID lg_ID     PA   WAR  \
# 225            CJ Abrams  682928.0     2025     WSN    NL  635.0  3.38
# 291         Wilyer Abreu  677800.0     2025     BOS    AL  417.0  3.21
# 387      Luisangel Acuña  682668.0     2025     NYM    NL  193.0  0.56
# 395     Ronald Acuña Jr.  660670.0     2025     ATL    NL  412.0  2.97
# 425         Willy Adames  642715.0     2025     SFG    NL  686.0  3.73
# 595          Riley Adams  656180.0     2025     WSN    NL  286.0  0.36
# 688             Jo Adell  666176.0     2025     LAA    AL  573.0  1.19
# 1013        Ozzie Albies  645277.0     2025     ATL    NL  667.0  2.10
# 1124     Blaze Alexander  677942.0     2025     ARI    NL  266.0  1.65
# 1572          Nick Allen  669397.0     2025     ATL    NL  416.0  0.62
# 1798         Pete Alonso  624413.0     2025     NYM    NL  709.0  3.43
# 1976         Jose Altuve  514888.0     2025     HOU    AL  654.0  0.49
# ...
